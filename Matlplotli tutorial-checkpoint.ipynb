# %% [markdown]
# ### Loas Necessaary library

# %%
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd

# %% [markdown]
# ###  Documention // https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.html

# %% [markdown]
# ### Basic Graph

# %%
x = [1,2,3]
y = [2,4,6]
plt.plot(x, y)
plt.title('Our First Graph!')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')
